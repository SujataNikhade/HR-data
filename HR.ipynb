# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

# %%
s=pd.read_csv('../DataSets/HR_Analytics.csv')

# %%
s
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
s.dtypes
# Out:
# employee_id               int64
# department               object
# region                   object
# education                object
# gender                   object
# recruitment_channel      object
# no_of_trainings           int64
# age                       int64
# previous_year_rating    float64
# length_of_service         int64
# KPIs_met >80%             int64
# awards_won?               int64
# avg_training_score        int64
# is_promoted               int64
# dtype: object

# %%
s.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               2409
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    4124
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# is_promoted                0
# dtype: int64

# %%
s.department.value_counts()
# Out:
# department
# Sales & Marketing    16840
# Operations           11348
# Technology            7138
# Procurement           7138
# Analytics             5352
# Finance               2536
# HR                    2418
# Legal                 1039
# R&D                    999
# Name: count, dtype: int64

# %%
s.gender.value_counts()
# Out:
# gender
# m    38496
# f    16312
# Name: count, dtype: int64

# %%
s.groupby('department')['length_of_service'].max()
# Out:
# department
# Analytics            34
# Finance              33
# HR                   33
# Legal                32
# Operations           34
# Procurement          32
# R&D                  20
# Sales & Marketing    37
# Technology           34
# Name: length_of_service, dtype: int64

# %%
pd.crosstab(index=s.department,columns=s.gender,margins='True')
# Out:
# gender                 f      m    All
# department
# Analytics            513   4839   5352
# Finance              681   1855   2536
# HR                  1006   1412   2418
# Legal                149    890   1039
# Operations          4677   6671  11348
# Procurement         3287   3851   7138
# R&D                   57    942    999
# Sales & Marketing   3154  13686  16840
# Technology          2788   4350   7138
# All                16312  38496  54808

# %%
pd.crosstab(index=s.department,columns=s.education,margins='True')
# Out:
# education          Bachelor's  Below Secondary  Master's & above    All
# department
# Analytics                3978                0              1037   5015
# Finance                  1895              106               499   2500
# HR                       1525              128               733   2386
# Legal                     814               65               156   1035
# Operations               7781              176              3165  11122
# Procurement              4393              129              2544   7066
# R&D                       542                0               429    971
# Sales & Marketing       11099                0              4166  15265
# Technology               4642              201              2196   7039
# All                     36669              805             14925  52399

# %%
s.region.value_counts()
# Out:
# region
# region_2     12343
# region_22     6428
# region_7      4843
# region_15     2808
# region_13     2648
# region_26     2260
# region_31     1935
# region_4      1703
# region_27     1659
# region_16     1465
# region_28     1318
# region_11     1315
# region_23     1175
# region_29      994
# region_32      945
# region_19      874
# region_20      850
# region_14      827
# region_25      819
# region_17      796
# region_5       766
# region_6       690
# region_30      657
# region_8       655
# region_10      648
# region_1       610
# region_24      508
# region_12      500
# region_9       420
# region_21      411
# region_3       346
# region_34      292
# region_33      269
# region_18       31
# Name: count, dtype: int64

# %%
s.recruitment_channel.unique()
# Out:
# array(['sourcing', 'other', 'referred'], dtype=object)

# %%
s.no_of_trainings.unique()
# Out:
# array([ 1,  2,  3,  4,  7,  5,  6,  8, 10,  9], dtype=int64)

# %%
s.no_of_trainings.value_counts()
# Out:
# no_of_trainings
# 1     44378
# 2      7987
# 3      1776
# 4       468
# 5       128
# 6        44
# 7        12
# 8         5
# 10        5
# 9         5
# Name: count, dtype: int64

# %%
s.describe()
# Out:
#         employee_id  no_of_trainings           age  previous_year_rating  \
# count  54808.000000     54808.000000  54808.000000          50684.000000
# mean   39195.830627         1.253011     34.803915              3.329256
# std    22586.581449         0.609264      7.660169              1.259993
# min        1.000000         1.000000     20.000000              1.000000
# 25%    19669.750000         1.000000     29.000000              3.000000
# 50%    39225.500000         1.000000     33.000000              3.000000
# 75%    58730.500000         1.000000     39.000000              4.000000
# max    78298.000000        10.000000     60.000000              5.000000
#
#        length_of_service  KPIs_met >80%   awards_won?  avg_training_score  \
# count       54808.000000   54808.000000  54808.000000        54808.000000
# mean            5.865512       0.351974      0.023172           63.386750
# std             4.265094       0.477590      0.150450           13.371559
# ...

# %%
s.length_of_service.value_counts()
# Out:
# length_of_service
# 3     7033
# 4     6836
# 2     6684
# 5     5832
# 7     5551
# 6     4734
# 1     4547
# 8     2883
# 9     2629
# 10    2193
# 11     916
# 12     794
# 13     687
# 15     593
# 14     549
# 16     548
# 17     432
# 18     392
# 19     329
# 20     128
# 21      78
# 24      70
# 23      65
# 22      61
# 25      51
# 26      41
# 27      36
# 28      30
# 29      30
# 31      20
# 30      12
# 32      10
# 33       9
# 34       4
# 37       1
# Name: count, dtype: int64

# %%
s.is_promoted.value_counts()
# Out:
# is_promoted
# 0    50140
# 1     4668
# Name: count, dtype: int64

# %%
s['KPIs_met >80%'].value_counts()
# Out:
# KPIs_met >80%
# 0    35517
# 1    19291
# Name: count, dtype: int64

# %%
s['awards_won?'].value_counts()
# Out:
# awards_won?
# 0    53538
# 1     1270
# Name: count, dtype: int64

# %%
s['KPIs_met']=s['KPIs_met >80%'].rename()

# %%
s
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
s['awards_won']=s['awards_won?'].rename()

# %%
s
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
#if we want to edit a more columns in one list then
s.drop(columns=['awards_won?','KPIs_met >80%'],inplace=True)

# %%
s
# Out:
#        employee_id         department     region         education gender  \
# 0            65438  Sales & Marketing   region_7  Master's & above      f
# 1            65141         Operations  region_22        Bachelor's      m
# 2             7513  Sales & Marketing  region_19        Bachelor's      m
# 3             2542  Sales & Marketing  region_23        Bachelor's      m
# 4            48945         Technology  region_26        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 54803         3030         Technology  region_14        Bachelor's      m
# 54804        74592         Operations  region_27  Master's & above      f
# 54805        13918          Analytics   region_1        Bachelor's      m
# 54806        13614  Sales & Marketing   region_9               NaN      m
# 54807        51526                 HR  region_22        Bachelor's      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# ...

# %%
s.groupby('department')['age'].mean()
# Out:
# department
# Analytics            32.431241
# Finance              32.058754
# HR                   34.385856
# Legal                33.832531
# Operations           36.073669
# Procurement          35.899972
# R&D                  32.842843
# Sales & Marketing    34.860629
# Technology           34.867190
# Name: age, dtype: float64

# %%
s.groupby('department')['avg_training_score'].max()
# Out:
# department
# Analytics            99
# Finance              98
# HR                   97
# Legal                97
# Operations           99
# Procurement          99
# R&D                  98
# Sales & Marketing    99
# Technology           99
# Name: avg_training_score, dtype: int64

# %%
pd.crosstab(index=s.region,columns=s.department,margins=True)
# Out:
# department  Analytics  Finance    HR  Legal  Operations  Procurement  R&D  \
# region
# region_1           76        7     7      1          61           18    0
# region_10          26       13    15      0          87          152    2
# region_11         128       57    41     22         281          174   47
# region_12          37       10     9     12         153           62    2
# region_13         133       87    83     32         540          425   26
# region_14          48       23    16      0         192          118    2
# region_15         234       76    67     18         965          360   31
# region_16          59       27    37     11         294          203   10
# region_17          26        1    19      3          92          349    2
# region_18           0        0     0      0           3            0    0
# region_19          66       20     6      1         363           85    4
# region_2          751      826   914    367        2133         2046  195
# ...

# %%
s.groupby('department')['length_of_service'].max()
# Out:
# department
# Analytics            34
# Finance              33
# HR                   33
# Legal                32
# Operations           34
# Procurement          32
# R&D                  20
# Sales & Marketing    37
# Technology           34
# Name: length_of_service, dtype: int64

# %%
pd.crosstab(index=s.recruitment_channel,columns=s.department,margins=True)
# Out:
# department           Analytics  Finance    HR  Legal  Operations  Procurement  \
# recruitment_channel
# other                     2973     1463  1380    590        6279         4002
# referred                    83        5   103     14         238           79
# sourcing                  2296     1068   935    435        4831         3057
# All                       5352     2536  2418   1039       11348         7138
#
# department           R&D  Sales & Marketing  Technology    All
# recruitment_channel
# other                555               9290        3914  30446
# referred              19                259         342   1142
# sourcing             425               7291        2882  23220
# All                  999              16840        7138  54808

# %%
pd.crosstab(index=s.education,columns=s.department,margins=True)
# Out:
# department        Analytics  Finance    HR  Legal  Operations  Procurement  \
# education
# Bachelor's             3978     1895  1525    814        7781         4393
# Below Secondary           0      106   128     65         176          129
# Master's & above       1037      499   733    156        3165         2544
# All                    5015     2500  2386   1035       11122         7066
#
# department        R&D  Sales & Marketing  Technology    All
# education
# Bachelor's        542              11099        4642  36669
# Below Secondary     0                  0         201    805
# Master's & above  429               4166        2196  14925
# All               971              15265        7039  52399

# %%
s.groupby('department')['employee_id'].sum()
# Out:
# department
# Analytics            209301691
# Finance              101257247
# HR                    96807617
# Legal                 39642336
# Operations           443990620
# Procurement          282026620
# R&D                   38203769
# Sales & Marketing    658546926
# Technology           278468259
# Name: employee_id, dtype: int64

# %%
pd.pivot_table(s,index='department',columns='region',values='KPIs_met',aggfunc='sum')
# Out:
# region             region_1  region_10  region_11  region_12  region_13  \
# department
# Analytics              33.0        7.0       55.0        5.0       45.0
# Finance                 4.0        5.0       24.0        8.0       38.0
# HR                      4.0        7.0       20.0        3.0       26.0
# Legal                   0.0        NaN        9.0       10.0        7.0
# Operations             34.0       35.0      108.0       67.0      259.0
# Procurement             2.0       56.0       76.0       23.0      171.0
# R&D                     NaN        1.0       18.0        1.0       15.0
# Sales & Marketing     135.0       55.0      105.0       46.0      257.0
# Technology             26.0       29.0       49.0        8.0      138.0
#
# region             region_14  region_15  region_16  region_17  region_18  ...  \
# department                                                                ...
# ...

# %%
s.groupby('department')['no_of_trainings'].max()
# Out:
# department
# Analytics             4
# Finance               5
# HR                    3
# Legal                 3
# Operations            5
# Procurement          10
# R&D                   5
# Sales & Marketing    10
# Technology            7
# Name: no_of_trainings, dtype: int64

# %%
pd.pivot_table(s,index='department',columns='recruitment_channel',values='length_of_service',aggfunc='max')
# Out:
# recruitment_channel  other  referred  sourcing
# department
# Analytics               34         9        27
# Finance                 28         5        33
# HR                      32        19        33
# Legal                   22         6        32
# Operations              33        19        34
# Procurement             32        19        32
# R&D                     20         7        16
# Sales & Marketing       34        19        37
# Technology              33        26        34

# %%
pd.pivot_table(s,index='department',columns='gender',values='awards_won',aggfunc='sum')
# Out:
# gender               f    m
# department
# Analytics           13  117
# Finance             25   45
# HR                  18   27
# Legal                3   22
# Operations         105  157
# Procurement         82   89
# R&D                  0   21
# Sales & Marketing   53  308
# Technology          70  115

# %%
pd.pivot_table(s,index='department',columns='gender',values='avg_training_score',aggfunc='max')
# Out:
# gender              f   m
# department
# Analytics          93  99
# Finance            98  98
# HR                 97  97
# Legal              71  97
# Operations         99  99
# Procurement        99  99
# R&D                91  98
# Sales & Marketing  99  99
# Technology         99  99

# %%
pd.pivot_table(s,index='department',columns='region',values='length_of_service',aggfunc='max')
# Out:
# region             region_1  region_10  region_11  region_12  region_13  \
# department
# Analytics              11.0       10.0       19.0        8.0       18.0
# Finance                 7.0        8.0       10.0        8.0       11.0
# HR                      5.0        8.0       13.0        7.0       15.0
# Legal                   6.0        NaN       10.0        7.0        9.0
# Operations             13.0       15.0       18.0       17.0       21.0
# Procurement             7.0       17.0       19.0       10.0       23.0
# R&D                     NaN        6.0       10.0        2.0       10.0
# Sales & Marketing      15.0       27.0       30.0       15.0       31.0
# Technology             13.0       21.0       17.0       10.0       34.0
#
# region             region_14  region_15  region_16  region_17  region_18  ...  \
# department                                                                ...
# ...
